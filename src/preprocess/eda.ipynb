# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import dash

# %%
data = pd.read_excel("/home/donerick/CI-CD-and-DVC-for-ML-projects/dvc_github_actions_proj/DATA/processed/df_prepare.xlsx")
data.head(10)
# Out:
#    consommation_energie classe_consommation_energie  estimation_ges  \
# 0                125.01                           C           29.25
# 1                 56.92                           B            3.20
# 2                 56.92                           B            3.20
# 3                233.16                           E           49.85
# 4                 49.61                           A           11.61
# 5                105.00                           C            1.00
# 6                199.00                           D           41.00
# 7                147.89                           C           44.37
# 8                484.90                           G           15.79
# 9                 52.54                           B            3.67
#
#   classe_estimation_ges  annee_construction  surface_thermique_lot   latitude  \
# 0                     D                2005                  81.59  45.948732
# ...

# %%
df = data.drop(columns=['numero_dpe', "nom_methode_dpe","version_methode_dpe",
                        "geo_adresse", 'tr002_type_batiment_description',
                        'tr001_modele_dpe_type_libelle'], axis=1)

df.head(10)
# Out:
#   date_etablissement_dpe  consommation_energie classe_consommation_energie  \
# 0             2015-10-07                125.01                           C
# 1             2016-01-25                 56.92                           B
# 2             2016-01-25                 56.92                           B
# 3             2016-01-28                233.16                           E
# 4             2015-09-02                 49.61                           A
# 5             2020-10-09                105.00                           C
# 6             2018-05-29                199.00                           D
# 7             2018-09-17                147.89                           C
# 8             2018-09-17                484.90                           G
# 9             2021-01-18                 52.54                           B
#
#    estimation_ges classe_estimation_ges  annee_construction  \
# 0           29.25                     D                2005
# ...

# %%
from tabulate import tabulate
df.describe(exclude='object')
# Out:
#            date_etablissement_dpe  consommation_energie  estimation_ges  \
# count                       10000          10000.000000    10000.000000
# mean   2017-09-21 14:20:58.560000             69.394509        7.294919
# min           2013-06-28 00:00:00           -115.360000        0.000000
# 25%           2015-06-26 00:00:00             46.537500        2.220000
# 50%           2015-11-30 00:00:00             56.340000        3.800000
# 75%           2020-07-27 00:00:00             70.842500       10.840000
# max           2021-06-04 00:00:00            606.000000      121.000000
# std                           NaN             56.048860        7.305478
#
#        annee_construction  surface_thermique_lot     latitude    longitude  \
# count        10000.000000           10000.000000  8168.000000  8168.000000
# mean          2015.441400             174.936832    47.284451     2.423420
# min              1.000000               0.000000    41.480909    -4.616028
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 13 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   consommation_energie          10000 non-null  float64
#  1   classe_consommation_energie   10000 non-null  object
#  2   estimation_ges                10000 non-null  float64
#  3   classe_estimation_ges         10000 non-null  object
#  4   annee_construction            10000 non-null  int64
#  5   surface_thermique_lot         10000 non-null  float64
#  6   latitude                      10000 non-null  float64
#  7   longitude                     10000 non-null  float64
#  8   code_insee_commune_actualise  9999 non-null   object
#  9   tv016_departement_code        10000 non-null  object
#  10  geo_score                     10000 non-null  float64
#  11  year                          10000 non-null  int64
# ...
